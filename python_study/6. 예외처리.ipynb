# %%
a = 10/0
a
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-8f523a4268b7> in <module>
# ----> 1 a = 10/0
#       2 a
#
# ZeroDivisionError: division by zero

# %%
try:
    a = 10 / 0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
# Out:
# 0으로 나눌 수 없습니다.

# %%
try:
    a = 10 / 0
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
else:
    print("에러 없이 끝났습니다.")
finally:
    print("모든 연산이 끝났습니다.")
# Out:
# 0으로 나눌 수 없습니다.
# 모든 연산이 끝났습니다.

# %%
Exception
# Out:
# Exception

# %%
try:
    a = 10/0
except Exception:
    print("에러 발생!")#모든 에러들은 Exception을 상속 받음
# Out:
# 에러 발생!

# %%
a=[3,4,5]
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-784eb532573a> in <module>
#       1 a=[3,4,5]
# ----> 2 print(a[3])
#
# IndexError: list index out of range

# %%
try :
    a=[3,4,5]
    print(a[3])  
except ZeroDivisionError:
    print("zero Division Errpr 발생")
except IndexError:
    print("Index Error 발생")
except Excetion:
    print("Exception")
# Out:
# Index Error 발생

# %%
raise Exception("에러발생")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-3e93b0536d76> in <module>
# ----> 1 raise Exception("에러발생")
#
# Exception: 에러발생

# %%
raise ValueError("Value Error 발생")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-65093d90af71> in <module>
# ----> 1 raise ValueError("Value Error 발생")
#
# ValueError: Value Error 발생

# %%
class NotMatchArgsError(Exception):#모든 Excetion은 상속
    pass

def calc(*args):
    if len(args) <2:
        raise NotMatchArgsErrpr

# %%
calc(45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3fb03e838747> in <module>
# ----> 1 calc(45)
#
# <ipython-input-15-7fcdb26e44af> in calc(*args)
#       4 def calc(*args):
#       5     if len(args) < 2:
# ----> 6         raise NotMatchArgsErrpr
#
# NameError: name 'NotMatchArgsErrpr' is not defined

# %% [markdown]
# # 모듈, 패키지

# %%
# !pip install requests

# %%
# calc.py
import calc

# %%
calc.add(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-cd25f919fd8f> in <module>
# ----> 1 calc.add(1,2,3)
#
# ~\sample_repo\calc.py in add(*args)
#       1 def add(*args):
# ----> 2     return sum(args)
#       3
#       4 def multiply(*args):
#       5     result =1
#
# NameError: name 'arg' is not defined

# %%
calc.multiply(3,4,5)
# Out:
# 60

# %%
from calc import add, multiply

# %%
add(5,6,7)
# Out:
# 18

# %%
multiply(3,4,5)
# Out:
# 60

# %%
from calc import multiply as _

# %%
_(3,4,5)
# Out:
# 60

# %%
from calc import *#모듈 안에 있는 것 모두다 import

# %%
import firstp

# %%
dir(firstp)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'func_a1',
#  'module_b1',
#  'modulea',
#  'moduleb']

# %%
import firstp.modulea as ma

# %%
ma.func_a1()
# Out:
# moduleA func1

# %%
from firstp.moduleb import module_b1
module_b1()
# Out:
# module B 1

# %%
import firstp

# %%
firstp.module_b1()
# Out:
# module B 1

# %%
import requests

# %%
resp = requests.get('https://www.naver.com')

# %%
resp.text
# Out:
# '\n<!doctype html>                <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양
# ...
