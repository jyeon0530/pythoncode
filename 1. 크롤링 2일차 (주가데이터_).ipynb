# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://finance.naver.com/item/sise.nhn'
params = {
    'code': '005930'
}
resp = requests.get(base_url, params=params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text)
day_sise = soup.find('iframe', attrs={'name': 'day'})
day_sise
# Out:
# <iframe bottommargin="0" frameborder="0" height="360" marginheight="0" name="day" scrolling="no" src="/item/sise_time.nhn?code=005930&amp;thistime=20200731095610" style="margin-top:20px;clear:both" title="주요 시세" topmargin="0" width="100%"></iframe>

# %% [markdown]
# ### 올바른 url

# %%
base_url = 'https://finance.naver.com/item/sise_day.nhn'
params = {
    'code': '005930'
}
resp = requests.get(base_url, params=params)
soup = BeautifulSoup(resp.text)

# %%
# soup.select('table.type2 tr')

# %%
tr_tags = soup.select('table.type2 tr')
len(tr_tags)
# Out:
# 16

# %%
result_list = []
th_tags = tr_tags[0].find_all('th')#TR tag의 0번째 목록

title_list = []
for th in th_tags:
    title_list.append(th.text)
print(title_list)
# Out:
# ['날짜', '종가', '전일비', '시가', '고가', '저가', '거래량']

# %%
result_list = []
for tr_tag in tr_tags:
    td_tags = tr_tag.find_all('td')
    if len(td_tags)<7:
        continue
        #td목록이 없으면 다음 번째로 넘어감
    
    data_list = []
    for td in td_tags:
        data_list.append(td.text.strip())
        
    result_list.append(
        dict(zip(title_list, data_list))
    )

# %%
def get_day_sise(code, page_num):
    base_url = 'https://finance.naver.com/item/sise_day.nhn'
    
    result_list = []
    for page in range(1, page_num+1):
        params = {
            'code': code,
            'page': page
        }

        resp = requests.get(base_url, params=params)
        soup = BeautifulSoup(resp.text)
        
        tr_tags = soup.select('table.type2 tr')
        th_tags = tr_tags[0].find_all('th')

        title_list = []
        for th in th_tags:
            title_list.append(th.text)
        
        
        for tr_tag in tr_tags:
            data_list = []
            td_tags = tr_tag.find_all('td')
            if len(td_tags)<7:
                continue
            for td in td_tags:
                data_list.append(td.text.strip())

            result_list.append(
                dict(zip(title_list, data_list))
            )

    return result_list

# %%
sise = get_day_sise('005930',5)

# %%
sise
# Out:
# [{'날짜': '2020.07.31',
#   '종가': '58,700',
#   '전일비': '300',
#   '시가': '59,500',
#   '고가': '59,600',
#   '저가': '58,400',
#   '거래량': '9,508,948'},
#  {'날짜': '2020.07.30',
#   '종가': '59,000',
#   '전일비': '0',
#   '시가': '59,700',
#   '고가': '60,100',
#   '저가': '59,000',
#   '거래량': '19,285,354'},
#  {'날짜': '2020.07.29',
#   '종가': '59,000',
#   '전일비': '400',
#   '시가': '60,300',
#   '고가': '60,400',
#   '저가': '58,600',
#   '거래량': '36,476,611'},
#  {'날짜': '2020.07.28',
#   '종가': '58,600',
#   '전일비': '3,000',
#   '시가': '57,000',
#   '고가': '58,800',
#   '저가': '56,400',
#   '거래량': '48,431,566'},
#  {'날짜': '2020.07.27',
#   '종가': '55,600',
#   '전일비': '1,400',
#   '시가': '54,300',
#   '고가': '55,700',
#   '저가': '54,300',
#   '거래량': '21,054,421'},
#  {'날짜': '2020.07.24',
#   '종가': '54,200',
#   '전일비': '100',
#   '시가': '54,000',
#   '고가': '54,400',
#   '저가': '53,700',
#   '거래량': '10,994,535'},
#  {'날짜': '2020.07.23',
#   '종가': '54,100',
#   '전일비': '600',
#   '시가': '54,700',
#   '고가': '54,700',
#   '저가': '53,800',
#   '거래량': '16,214,932'},
#  {'날짜': '2020.07.22',
#   '종가': '54,700',
#   '전일비': '600',
#   '시가': '55,300',
#   '고가': '55,500',
#   '저가': '54,700',
#   '거래량': '12,885,057'},
#  {'날짜': '2020.07.21',
#   '종가': '55,300',
#   '전일비': '1,100',
#   '시가': '55,200',
#   '고가': '55,400',
#   '저가': '54,800',
#   '거래량': '18,297,260'},
#  {'날짜': '2020.07.20',
#   '종가': '54,200',
#   '전일비': '200',
#   '시가': '54,800',
#   '고가': '54,800',
#   '저가': '54,000',
#   '거래량': '10,507,530'},
#  {'날짜': '2020.07.17',
#   '종가': '54,400',
#   '전일비': '600',
#   '시가': '54,200',
#   '고가': '54,700',
#   '저가': '54,100',
#   '거래량': '10,096,174'},
#  {'날짜': '2020.07.16',
#   '종가': '53,800',
#   '전일비': '900',
#   '시가': '54,800',
#   '고가': '54,800',
#   '저가': '53,800',
#   '거래량': '16,779,127'},
#  {'날짜': '2020.07.15',
#   '종가': '54,700',
#   '전일비': '900',
#   '시가': '54,400',
#   '고가': '55,000',
#   '저가': '54,300',
#   '거래량': '24,051,450'},
#  {'날짜': '2020.07.14',
#   '종가': '53,800',
#   '전일비': '400',
#   '시가': '53,700',
#   '고가': '53,800',
#   '저가': '53,200',
#   '거래량': '14,269,484'},
#  {'날짜': '2020.07.13',
#   '종가': '53,400',
#   '전일비': '700',
#   '시가': '53,300',
#   '고가': '53,800',
#   '저가': '53,100',
#   '거래량': '12,240,188'},
#  {'날짜': '2020.07.10',
#   '종가': '52,700',
#   '전일비': '100',
#   '시가': '53,100',
#   '고가': '53,200',
#   '저가': '52,300',
#   '거래량': '13,714,746'},
#  {'날짜': '2020.07.09',
#   '종가': '52,800',
#   '전일비': '200',
#   '시가': '53,200',
#   '고가': '53,600',
#   '저가': '52,800',
#   '거래량': '17,054,850'},
#  {'날짜': '2020.07.08',
#   '종가': '53,000',
#   '전일비': '400',
#   '시가': '53,600',
#   '고가': '53,900',
#   '저가': '52,900',
#   '거래량': '19,664,652'},
#  {'날짜': '2020.07.07',
#   '종가': '53,400',
#   '전일비': '1,600',
#   '시가': '55,800',
#   '고가': '55,900',
#   '저가': '53,400',
#   '거래량': '30,760,032'},
#  {'날짜': '2020.07.06',
#   '종가': '55,000',
#   '전일비': '1,400',
#   '시가': '54,000',
#   '고가': '55,000',
#   '저가': '53,800',
#   '거래량': '19,856,623'},
#  {'날짜': '2020.07.03',
#   '종가': '53,600',
#   '전일비': '700',
#   '시가': '53,000',
#   '고가': '53,600',
#   '저가': '52,700',
#   '거래량': '11,887,868'},
#  {'날짜': '2020.07.02',
#   '종가': '52,900',
#   '전일비': '300',
#   '시가': '52,100',
#   '고가': '52,900',
#   '저가': '52,100',
#   '거래량': '14,142,583'},
#  {'날짜': '2020.07.01',
#   '종가': '52,600',
#   '전일비': '200',
#   '시가': '53,400',
#   '고가': '53,600',
#   '저가': '52,400',
#   '거래량': '16,706,143'},
#  {'날짜': '2020.06.30',
#   '종가': '52,800',
#   '전일비': '400',
#   '시가': '53,900',
#   '고가': '53,900',
#   '저가': '52,800',
#   '거래량': '21,157,172'},
#  {'날짜': '2020.06.29',
#   '종가': '52,400',
#   '전일비': '900',
#   '시가': '52,500',
#   '고가': '53,200',
#   '저가': '52,000',
#   '거래량': '17,776,925'},
#  {'날짜': '2020.06.26',
#   '종가': '53,300',
#   '전일비': '1,400',
#   '시가': '52,800',
#   '고가': '53,900',
#   '저가': '52,200',
#   '거래량': '21,575,360'},
#  {'날짜': '2020.06.25',
#   '종가': '51,900',
#   '전일비': '1,000',
#   '시가': '52,100',
#   '고가': '53,000',
#   '저가': '51,900',
#   '거래량': '18,541,624'},
#  {'날짜': '2020.06.24',
#   '종가': '52,900',
#   '전일비': '1,500',
#   '시가': '51,900',
#   '고가': '53,900',
#   '저가': '51,600',
#   '거래량': '24,519,552'},
#  {'날짜': '2020.06.23',
#   '종가': '51,400',
#   '전일비': '600',
#   '시가': '52,500',
#   '고가': '52,800',
#   '저가': '51,100',
#   '거래량': '18,086,152'},
#  {'날짜': '2020.06.22',
#   '종가': '52,000',
#   '전일비': '900',
#   '시가': '52,000',
#   '고가': '52,600',
#   '저가': '51,800',
#   '거래량': '13,801,350'},
#  {'날짜': '2020.06.19',
#   '종가': '52,900',
#   '전일비': '600',
#   '시가': '52,600',
#   '고가': '52,900',
#   '저가': '51,600',
#   '거래량': '18,157,985'},
#  {'날짜': '2020.06.18',
#   '종가': '52,300',
#   '전일비': '100',
#   '시가': '52,200',
#   '고가': '52,300',
#   '저가': '51,600',
#   '거래량': '15,982,926'},
#  {'날짜': '2020.06.17',
#   '종가': '52,200',
#   '전일비': '100',
#   '시가': '52,100',
#   '고가': '52,900',
#   '저가': '51,300',
#   '거래량': '26,672,595'},
#  {'날짜': '2020.06.16',
#   '종가': '52,100',
#   '전일비': '2,200',
#   '시가': '51,200',
#   '고가': '52,100',
#   '저가': '50,600',
#   '거래량': '21,808,375'},
#  {'날짜': '2020.06.15',
#   '종가': '49,900',
#   '전일비': '2,400',
#   '시가': '51,400',
#   '고가': '52,000',
#   '저가': '49,900',
#   '거래량': '28,772,921'},
#  {'날짜': '2020.06.12',
#   '종가': '52,300',
#   '전일비': '2,000',
#   '시가': '52,100',
#   '고가': '52,800',
#   '저가': '51,500',
#   '거래량': '26,976,019'},
#  {'날짜': '2020.06.11',
#   '종가': '54,300',
#   '전일비': '1,100',
#   '시가': '54,500',
#   '고가': '55,100',
#   '저가': '53,200',
#   '거래량': '33,815,123'},
#  {'날짜': '2020.06.10',
#   '종가': '55,400',
#   '전일비': '100',
#   '시가': '55,100',
#   '고가': '55,900',
#   '저가': '54,900',
#   '거래량': '16,742,493'},
#  {'날짜': '2020.06.09',
#   '종가': '55,500',
#   '전일비': '600',
#   '시가': '55,800',
#   '고가': '56,500',
#   '저가': '54,400',
#   '거래량': '23,998,831'},
#  {'날짜': '2020.06.08',
#   '종가': '54,900',
#   '전일비': '600',
#   '시가': '56,400',
#   '고가': '56,500',
#   '저가': '54,700',
#   '거래량': '25,634,965'},
#  {'날짜': '2020.06.05',
#   '종가': '55,500',
#   '전일비': '900',
#   '시가': '54,400',
#   '고가': '55,900',
#   '저가': '54,000',
#   '거래량': '22,743,629'},
#  {'날짜': '2020.06.04',
#   '종가': '54,600',
#   '전일비': '100',
#   '시가': '55,800',
#   '고가': '57,000',
#   '저가': '54,600',
#   '거래량': '40,220,334'},
#  {'날짜': '2020.06.03',
#   '종가': '54,500',
#   '전일비': '3,100',
#   '시가': '51,800',
#   '고가': '55,000',
#   '저가': '51,700',
#   '거래량': '49,257,814'},
#  {'날짜': '2020.06.02',
#   '종가': '51,400',
#   '전일비': '200',
#   '시가': '51,000',
#   '고가': '51,500',
#   '저가': '50,800',
#   '거래량': '14,247,933'},
#  {'날짜': '2020.06.01',
#   '종가': '51,200',
#   '전일비': '500',
#   '시가': '50,800',
#   '고가': '51,200',
#   '저가': '50,600',
#   '거래량': '16,949,183'},
#  {'날짜': '2020.05.29',
#   '종가': '50,700',
#   '전일비': '300',
#   '시가': '50,000',
#   '고가': '50,700',
#   '저가': '49,700',
#   '거래량': '27,596,961'},
#  {'날짜': '2020.05.28',
#   '종가': '50,400',
#   '전일비': '500',
#   '시가': '51,100',
#   '고가': '51,200',
#   '저가': '49,900',
#   '거래량': '31,309,318'},
#  {'날짜': '2020.05.27',
#   '종가': '49,900',
#   '전일비': '650',
#   '시가': '48,950',
#   '고가': '50,000',
#   '저가': '48,800',
#   '거래량': '19,548,479'},
#  {'날짜': '2020.05.26',
#   '종가': '49,250',
#   '전일비': '400',
#   '시가': '48,700',
#   '고가': '49,450',
#   '저가': '48,600',
#   '거래량': '15,127,490'},
#  {'날짜': '2020.05.25',
#   '종가': '48,850',
#   '전일비': '100',
#   '시가': '48,750',
#   '고가': '48,900',
#   '저가': '48,450',
#   '거래량': '14,337,913'}]

# %% [markdown]
# ### Pandas Excel(csv) IO

# %%
import pandas as pd

# %%
sise_df = pd.DataFrame(sise)
sise_df
# Out:
#             날짜      종가    전일비      시가      고가      저가         거래량
# 0   2020.07.31  58,700    300  59,500  59,600  58,400   9,508,948
# 1   2020.07.30  59,000      0  59,700  60,100  59,000  19,285,354
# 2   2020.07.29  59,000    400  60,300  60,400  58,600  36,476,611
# 3   2020.07.28  58,600  3,000  57,000  58,800  56,400  48,431,566
# 4   2020.07.27  55,600  1,400  54,300  55,700  54,300  21,054,421
# 5   2020.07.24  54,200    100  54,000  54,400  53,700  10,994,535
# 6   2020.07.23  54,100    600  54,700  54,700  53,800  16,214,932
# 7   2020.07.22  54,700    600  55,300  55,500  54,700  12,885,057
# 8   2020.07.21  55,300  1,100  55,200  55,400  54,800  18,297,260
# 30  2020.06.19  52,900    600  52,600  52,900  51,600  18,157,985
# 31  2020.06.18  52,300    100  52,200  52,300  51,600  15,982,926
# 32  2020.06.17  52,200    100  52,100  52,900  51,300  26,672,595
# 33  2020.06.16  52,100  2,200  51,200  52,100  50,600  21,808,375
# 34  2020.06.15  49,900  2,400  51,400  52,000  49,900  28,772,921
# 35  2020.06.12  52,300  2,000  52,100  52,800  51,500  26,976,019
# 36  2020.06.11  54,300  1,100  54,500  55,100  53,200  33,815,123
# 37  2020.06.10  55,400    100  55,100  55,900  54,900  16,742,493
# 38  2020.06.09  55,500    600  55,800  56,500  54,400  23,998,831
# 39  2020.06.08  54,900    600  56,400  56,500  54,700  25,634,965
# 40  2020.06.05  55,500    900  54,400  55,900  54,000  22,743,629
# 41  2020.06.04  54,600    100  55,800  57,000  54,600  40,220,334
# 42  2020.06.03  54,500  3,100  51,800  55,000  51,700  49,257,814
# 43  2020.06.02  51,400    200  51,000  51,500  50,800  14,247,933
# 44  2020.06.01  51,200    500  50,800  51,200  50,600  16,949,183
# 45  2020.05.29  50,700    300  50,000  50,700  49,700  27,596,961
# 46  2020.05.28  50,400    500  51,100  51,200  49,900  31,309,318
# 47  2020.05.27  49,900    650  48,950  50,000  48,800  19,548,479
# 48  2020.05.26  49,250    400  48,700  49,450  48,600  15,127,490
# 49  2020.05.25  48,850    100  48,750  48,900  48,450  14,337,913

# %% [markdown]
# # Selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('https://www.naver.com')

# %%
driver.title
# Out:
# 'NAVER'

# %%
group_nav = driver.find_element_by_class_name('group_nav')
group_nav
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="3fcc5cad-d4f2-4902-bd61-103421287d69")>

# %%
nav_items = group_nav.find_elements_by_class_name('nav_item')
nav_items
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="0841ae0a-3991-40e3-8002-c6ead2207d7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="ffe7fd44-5645-444d-b522-3fed952468d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="a6d54f33-621b-4c44-8b5d-72d24808b330")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="7c910c45-66cb-45b9-bd2c-8e0a9adb8798")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="f5482b7e-2001-420b-ba0d-379ff1c23e3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="8b5c7abe-5624-4ae8-9417-ac4aa207a17b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="bfa924f0-7651-495f-b7ea-c2135957924f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="05f200df-e8db-48b5-bf72-69ce4aa63946")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="12432359-a9b5-45e6-ac09-89fe9184788c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="8783dd78-4297-4f51-bf07-43cfcfc4f190")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="793c3c78-b78f-4435-b782-fb5b45515abf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="eb1c0bee-8f40-41c3-a255-ddb88239e833")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="2e77f9a1-6a62-46b7-bc4a-51155033ada5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="55d065e4-2ed2-4b6d-96e0-84b580030874")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="14522cd2-a4ef-41e5-8e1b-52b4704a7e8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="00b86bf0-4fdb-4c86-898f-328b5056cb01")>]

# %%
result_list= [] 
for nav in nav_items:
    anchor_tag = nav.find_element_by_tag_name('a')
    result_list.append({
        'url': anchor_tag.get_attribute('href'),
        'title': anchor_tag.text
    })

# %%
result_list
# Out:
# [{'url': 'https://mail.naver.com/', 'title': '메일'},
#  {'url': 'https://section.cafe.naver.com/', 'title': '카페'},
#  {'url': 'https://section.blog.naver.com/', 'title': '블로그'},
#  {'url': 'https://kin.naver.com/', 'title': '지식iN'},
#  {'url': 'https://shopping.naver.com/', 'title': '쇼핑'},
#  {'url': 'https://order.pay.naver.com/home', 'title': 'Pay'},
#  {'url': 'https://tv.naver.com/', 'title': 'TV'},
#  {'url': 'https://dict.naver.com/', 'title': '사전'},
#  {'url': 'https://news.naver.com/', 'title': '뉴스'},
#  {'url': 'https://finance.naver.com/', 'title': '증권'},
#  {'url': 'https://land.naver.com/', 'title': '부동산'},
#  {'url': 'https://map.naver.com/', 'title': '지도'},
#  {'url': 'https://movie.naver.com/', 'title': '영화'},
#  {'url': 'https://vibe.naver.com/?from=naver_main', 'title': '뮤직'},
#  {'url': 'https://book.naver.com/', 'title': '책'},
#  {'url': 'https://comic.naver.com/', 'title': '웹툰'}]

# %%
driver.get_window_size()
# Out:
# {'width': 1936, 'height': 1056}

# %%
driver.back()

# %%
driver.forward()

# %%
search_input = driver.find_element_by_id('query')
search_input
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="348ff4a059d5cd90e9f669bdefe207de", element="13d86ea9-cf3e-4d32-8df4-1eb7d52a6784")>

# %%
search_input.send_keys('방탄소년단')

# %%
search_btn = driver.find_element_by_id('search_btn')
search_btn.click()

# %%
driver.current_url
# Out:
# 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8'

# %% [markdown]
# ## selenium 3페이지뉴스
# 브라우저를 핸들링하는 것 !리퀴스트를 날려주는 것이 아님!

# %%
driver = webdriver.Chrome()

# %%
result_list = []

for i in range(10):
    url = 'https://search.naver.com/search.naver?query=방탄소년단&where=news&start={}'.format(i*10+1)#페이지 넘어가기
    driver.get(url)#**URL가져오기
    
    a_tags = driver.find_elements_by_class_name('_sp_each_title')
    for a in a_tags:
        result_list.append({
            'url': a.get_attribute('href'),
            'title':a.text
        })

# %%
result_list[1], result_list[11], result_list[21], result_list[31]
# Out:
# ({'url': 'http://sports.khan.co.kr/news/sk_index.html?art_id=202007310956003&sec_id=540101&pt=nv',
#   'title': '방탄소년단 뷔랑 여름휴가 어때?'},
#  {'url': 'http://news.heraldcorp.com/view.php?ud=20200731000121',
#   'title': '방탄소년단 ‘방방콘’·코심, 코로나 시대의 문화예술 활동으로 필리핀 소개'},
#  {'url': 'http://star.mt.co.kr/stview.php?no=2020073009453108321',
#   'title': '"특히 태형을 위해서라면" 방탄소년단 뷔에 적극 구애한 에어비엔비'},
#  {'url': 'http://www.businesspost.co.kr/BP?command=article_view&num=189549',
#   'title': "엔터테인먼트3사 주가 다 올라, '방탄소년단 테마주'도 대체로 상승"})

# %%
# driver에서 js 실행시키기.
# js를 알아야한다..
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.get('https://www.wadiz.kr/web/wreward/main?keyword=&endYn=ALL&order=recommend')
import time
for i in range(100):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-6087db3c450f> in <module>
#       3 for i in range(100):
#       4     driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
# ----> 5     time.sleep(3)
#
# KeyboardInterrupt:

# %%
screenshot = diver.get_screenshot_as_png("wadiz.png")

# %%
diver.page_source

# %% [markdown]
# # Json with dynamic DOM

# %% [markdown]
# # json

# %%
base_url = "https://crix-api-cdn.upbit.com/v1/crix/candles/months"
params = {
    'code': 'CRIX.UPBIT.KRW-BTC',
    'count':'200',
}
resp = requests.get(base_url, params=params)

# %%
import json

# %%
month_candle = json.loads(resp.text)
month_candle
# Out:
# [{'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-07-01T09:00:00+09:00',
#   'openingPrice': 10903000.0,
#   'highPrice': 13368000.0,
#   'lowPrice': 10700000.0,
#   'tradePrice': 13110000.0,
#   'candleAccTradeVolume': 83274.16530314,
#   'candleAccTradePrice': 973772272323.6138,
#   'timestamp': 1596179406533,
#   'firstDayOfPeriod': '2020-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-06-01T09:00:00+09:00',
#   'openingPrice': 11432000.0,
#   'highPrice': 12230000.0,
#   'lowPrice': 10756000.0,
#   'tradePrice': 10903000.0,
#   'candleAccTradeVolume': 82842.86826319,
#   'candleAccTradePrice': 947354527390.6284,
#   'timestamp': 1593561601838,
#   'firstDayOfPeriod': '2020-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-05-01T09:00:00+09:00',
#   'openingPrice': 10477000.0,
#   'highPrice': 12163000.0,
#   'lowPrice': 10121000.0,
#   'tradePrice': 11432000.0,
#   'candleAccTradeVolume': 188722.04592686,
#   'candleAccTradePrice': 2109939228782.646,
#   'timestamp': 1590969594783,
#   'firstDayOfPeriod': '2020-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-04-01T09:00:00+09:00',
#   'openingPrice': 7799000.0,
#   'highPrice': 11435000.0,
#   'lowPrice': 7529000.0,
#   'tradePrice': 10477000.0,
#   'candleAccTradeVolume': 171519.60064021,
#   'candleAccTradePrice': 1524309595907.389,
#   'timestamp': 1588291200393,
#   'firstDayOfPeriod': '2020-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-03-01T09:00:00+09:00',
#   'openingPrice': 10380000.0,
#   'highPrice': 10980000.0,
#   'lowPrice': 5489000.0,
#   'tradePrice': 7799000.0,
#   'candleAccTradeVolume': 345309.78188922,
#   'candleAccTradePrice': 2661304476282.0654,
#   'timestamp': 1585699199936,
#   'firstDayOfPeriod': '2020-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-02-01T09:00:00+09:00',
#   'openingPrice': 10781000.0,
#   'highPrice': 12044000.0,
#   'lowPrice': 10306000.0,
#   'tradePrice': 10374000.0,
#   'candleAccTradeVolume': 141681.39512565,
#   'candleAccTradePrice': 1608632370095.7415,
#   'timestamp': 1583020800101,
#   'firstDayOfPeriod': '2020-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-01-01T09:00:00+09:00',
#   'openingPrice': 8308000.0,
#   'highPrice': 10882000.0,
#   'lowPrice': 7910000.0,
#   'tradePrice': 10781000.0,
#   'candleAccTradeVolume': 151081.46125133,
#   'candleAccTradePrice': 1448009639610.1118,
#   'timestamp': 1580515200123,
#   'firstDayOfPeriod': '2020-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-12-01T09:00:00+09:00',
#   'openingPrice': 8838000.0,
#   'highPrice': 8996000.0,
#   'lowPrice': 7546000.0,
#   'tradePrice': 8312000.0,
#   'candleAccTradeVolume': 88753.43949787,
#   'candleAccTradePrice': 749631042779.4087,
#   'timestamp': 1577836799562,
#   'firstDayOfPeriod': '2019-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-11-01T09:00:00+09:00',
#   'openingPrice': 10698000.0,
#   'highPrice': 10996000.0,
#   'lowPrice': 7683000.0,
#   'tradePrice': 8838000.0,
#   'candleAccTradeVolume': 121988.83863801,
#   'candleAccTradePrice': 1142572317699.0076,
#   'timestamp': 1575158386426,
#   'firstDayOfPeriod': '2019-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-10-01T09:00:00+09:00',
#   'openingPrice': 9945000.0,
#   'highPrice': 11899000.0,
#   'lowPrice': 8630000.0,
#   'tradePrice': 10692000.0,
#   'candleAccTradeVolume': 158003.54559607,
#   'candleAccTradePrice': 1604730480108.4348,
#   'timestamp': 1572566396750,
#   'firstDayOfPeriod': '2019-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-09-01T09:00:00+09:00',
#   'openingPrice': 11612000.0,
#   'highPrice': 13014000.0,
#   'lowPrice': 9268000.0,
#   'tradePrice': 9945000.0,
#   'candleAccTradeVolume': 152291.29161581,
#   'candleAccTradePrice': 1748379097342.2788,
#   'timestamp': 1569887998676,
#   'firstDayOfPeriod': '2019-09-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-08-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-08-01T09:00:00+09:00',
#   'openingPrice': 11956000.0,
#   'highPrice': 14570000.0,
#   'lowPrice': 11380000.0,
#   'tradePrice': 11612000.0,
#   'candleAccTradeVolume': 283765.53137123,
#   'candleAccTradePrice': 3661279344006.8315,
#   'timestamp': 1567295999820,
#   'firstDayOfPeriod': '2019-08-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-07-01T09:00:00+09:00',
#   'openingPrice': 13599000.0,
#   'highPrice': 15537000.0,
#   'lowPrice': 10880000.0,
#   'tradePrice': 11957000.0,
#   'candleAccTradeVolume': 487170.94062848,
#   'candleAccTradePrice': 6321462071944.682,
#   'timestamp': 1564617599890,
#   'firstDayOfPeriod': '2019-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-06-01T09:00:00+09:00',
#   'openingPrice': 10383000.0,
#   'highPrice': 16840000.0,
#   'lowPrice': 9172000.0,
#   'tradePrice': 13598000.0,
#   'candleAccTradeVolume': 395517.38569837,
#   'candleAccTradePrice': 4981181503052.697,
#   'timestamp': 1561939201202,
#   'firstDayOfPeriod': '2019-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-05-01T09:00:00+09:00',
#   'openingPrice': 6117000.0,
#   'highPrice': 10815000.0,
#   'lowPrice': 6107000.0,
#   'tradePrice': 10383000.0,
#   'candleAccTradeVolume': 364387.76327154,
#   'candleAccTradePrice': 3225143397528.754,
#   'timestamp': 1559347198750,
#   'firstDayOfPeriod': '2019-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-04-01T09:00:00+09:00',
#   'openingPrice': 4661000.0,
#   'highPrice': 6566000.0,
#   'lowPrice': 4621000.0,
#   'tradePrice': 6117000.0,
#   'candleAccTradeVolume': 286261.8481024,
#   'candleAccTradePrice': 1666238307040.8777,
#   'timestamp': 1556668799842,
#   'firstDayOfPeriod': '2019-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-03-01T09:00:00+09:00',
#   'openingPrice': 4240000.0,
#   'highPrice': 4680000.0,
#   'lowPrice': 4120000.0,
#   'tradePrice': 4661000.0,
#   'candleAccTradeVolume': 220183.66257353,
#   'candleAccTradePrice': 971178898630.9796,
#   'timestamp': 1554076797634,
#   'firstDayOfPeriod': '2019-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-02-01T09:00:00+09:00',
#   'openingPrice': 3775000.0,
#   'highPrice': 4554000.0,
#   'lowPrice': 3735000.0,
#   'tradePrice': 4240000.0,
#   'candleAccTradeVolume': 149447.01330811,
#   'candleAccTradePrice': 613176329271.873,
#   'timestamp': 1551398399461,
#   'firstDayOfPeriod': '2019-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-01-01T09:00:00+09:00',
#   'openingPrice': 4200000.0,
#   'highPrice': 4577000.0,
#   'lowPrice': 3730000.0,
#   'tradePrice': 3775000.0,
#   'candleAccTradeVolume': 152628.16488031,
#   'candleAccTradePrice': 625565113869.71,
#   'timestamp': 1548979197516,
#   'firstDayOfPeriod': '2019-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-12-01T09:00:00+09:00',
#   'openingPrice': 4565000.0,
#   'highPrice': 4852000.0,
#   'lowPrice': 3562000.0,
#   'tradePrice': 4200000.0,
#   'candleAccTradeVolume': 256196.68711434,
#   'candleAccTradePrice': 1077286128289.1417,
#   'timestamp': 1546300799298,
#   'firstDayOfPeriod': '2018-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-11-01T09:00:00+09:00',
#   'openingPrice': 7162000.0,
#   'highPrice': 7348000.0,
#   'lowPrice': 4126000.0,
#   'tradePrice': 4565000.0,
#   'candleAccTradeVolume': 202770.0644728,
#   'candleAccTradePrice': 1119919084873.1338,
#   'timestamp': 1543622399999,
#   'firstDayOfPeriod': '2018-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-10-01T09:00:00+09:00',
#   'openingPrice': 7394000.0,
#   'highPrice': 7905000.0,
#   'lowPrice': 7057000.0,
#   'tradePrice': 7162000.0,
#   'candleAccTradeVolume': 101664.52766478,
#   'candleAccTradePrice': 746729084717.5271,
#   'timestamp': 1541030395761,
#   'firstDayOfPeriod': '2018-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-09-01T09:00:00+09:00',
#   'openingPrice': 7865000.0,
#   'highPrice': 8333000.0,
#   'lowPrice': 7010000.0,
#   'tradePrice': 7393000.0,
#   'candleAccTradeVolume': 100674.26100622,
#   'candleAccTradePrice': 751712331036.9186,
#   'timestamp': 1538351998003,
#   'firstDayOfPeriod': '2018-09-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-08-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-08-01T09:00:00+09:00',
#   'openingPrice': 8807000.0,
#   'highPrice': 8940000.0,
#   'lowPrice': 6960000.0,
#   'tradePrice': 7865000.0,
#   'candleAccTradeVolume': 150764.1511383,
#   'candleAccTradePrice': 1160146596428.6897,
#   'timestamp': 1535759997980,
#   'firstDayOfPeriod': '2018-08-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-07-01T09:00:00+09:00',
#   'openingPrice': 7164000.0,
#   'highPrice': 9578000.0,
#   'lowPrice': 6941000.0,
#   'tradePrice': 8800000.0,
#   'candleAccTradeVolume': 181398.01589799,
#   'candleAccTradePrice': 1496143560056.306,
#   'timestamp': 1533081602111,
#   'firstDayOfPeriod': '2018-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-06-01T09:00:00+09:00',
#   'openingPrice': 8278000.0,
#   'highPrice': 8490000.0,
#   'lowPrice': 6590000.0,
#   'tradePrice': 7164000.0,
#   'candleAccTradeVolume': 117782.95477841,
#   'candleAccTradePrice': 884389892618.8875,
#   'timestamp': 1530403203921,
#   'firstDayOfPeriod': '2018-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-05-01T09:00:00+09:00',
#   'openingPrice': 10135000.0,
#   'highPrice': 10963000.0,
#   'lowPrice': 7813000.0,
#   'tradePrice': 8282000.0,
#   'candleAccTradeVolume': 272267.48145009,
#   'candleAccTradePrice': 2607958006238.1025,
#   'timestamp': 1527811206423,
#   'firstDayOfPeriod': '2018-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-04-01T09:00:00+09:00',
#   'openingPrice': 7688000.0,
#   'highPrice': 10755000.0,
#   'lowPrice': 7087000.0,
#   'tradePrice': 10138000.0,
#   'candleAccTradeVolume': 573633.81153136,
#   'candleAccTradePrice': 4959892531222.687,
#   'timestamp': 1525132804146,
#   'firstDayOfPeriod': '2018-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-03-01T09:00:00+09:00',
#   'openingPrice': 11865000.0,
#   'highPrice': 12899000.0,
#   'lowPrice': 7431000.0,
#   'tradePrice': 7697000.0,
#   'candleAccTradeVolume': 575945.75756607,
#   'candleAccTradePrice': 5805373843215.382,
#   'timestamp': 1522540804153,
#   'firstDayOfPeriod': '2018-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-02-01T09:00:00+09:00',
#   'openingPrice': 11439000.0,
#   'highPrice': 14149000.0,
#   'lowPrice': 6620000.0,
#   'tradePrice': 11860000.0,
#   'candleAccTradeVolume': 780683.9588336,
#   'candleAccTradePrice': 8338553933032.581,
#   'timestamp': 1519862403088,
#   'firstDayOfPeriod': '2018-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-01-01T09:00:00+09:00',
#   'openingPrice': 19278000.0,
#   'highPrice': 28885000.0,
#   'lowPrice': 10400000.0,
#   'tradePrice': 11429000.0,
#   'candleAccTradeVolume': 1138495.89407868,
#   'candleAccTradePrice': 20968342926307.7,
#   'timestamp': 1517443201774,
#   'firstDayOfPeriod': '2018-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-12-01T09:00:00+09:00',
#   'openingPrice': 11935000.0,
#   'highPrice': 24967000.0,
#   'lowPrice': 11201000.0,
#   'tradePrice': 19280000.0,
#   'candleAccTradeVolume': 1423404.06885122,
#   'candleAccTradePrice': 27132793421335.008,
#   'timestamp': 1514764800514,
#   'firstDayOfPeriod': '2017-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-11-01T09:00:00+09:00',
#   'openingPrice': 7422000.0,
#   'highPrice': 13750000.0,
#   'lowPrice': 6476000.0,
#   'tradePrice': 11935000.0,
#   'candleAccTradeVolume': 332870.40658095,
#   'candleAccTradePrice': 3333919267614.687,
#   'timestamp': 1512086401121,
#   'firstDayOfPeriod': '2017-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-10-01T09:00:00+09:00',
#   'openingPrice': 4889000.0,
#   'highPrice': 7479000.0,
#   'lowPrice': 4682000.0,
#   'tradePrice': 7422000.0,
#   'candleAccTradeVolume': 4282.09567791,
#   'candleAccTradePrice': 28792318723.58634,
#   'timestamp': 1509494399256,
#   'firstDayOfPeriod': '2017-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-09-01T09:00:00+09:00',
#   'openingPrice': 4201000.0,
#   'highPrice': 4896000.0,
#   'lowPrice': 4175000.0,
#   'tradePrice': 4895000.0,
#   'candleAccTradeVolume': 347.48185656,
#   'candleAccTradePrice': 1544805967.39643,
#   'timestamp': 1506815987704,
#   'firstDayOfPeriod': '2017-09-01'}]

# %%
month_candle[0]
# Out:
# {'code': 'CRIX.UPBIT.KRW-BTC',
#  'candleDateTime': '2020-07-01T00:00:00+00:00',
#  'candleDateTimeKst': '2020-07-01T09:00:00+09:00',
#  'openingPrice': 10903000.0,
#  'highPrice': 13368000.0,
#  'lowPrice': 10700000.0,
#  'tradePrice': 13038000.0,
#  'candleAccTradeVolume': 82973.98783208,
#  'candleAccTradePrice': 969841584833.2474,
#  'timestamp': 1596172888346,
#  'firstDayOfPeriod': '2020-07-01'}

# %%
month_candle[0]['lowPrice']
# Out:
# 10700000.0

# %%
#파이썬 객체를 json객체로 바꿈
month_json = json.dumps(month_candle)
month_json
# Out:
# '[{"code": "CRIX.UPBIT.KRW-BTC", "candleDateTime": "2020-07-01T00:00:00+00:00", "candleDateTimeKst": "2020-07-01T09:00:00+09:00", "openingPrice": 10903000.0, "highPrice": 13368000.0, "lowPrice": 10700000.0, "tradePrice": 13038000.0, "candleAccTradeVolume": 82973.98783208, "candleAccTradePrice": 969841584833.2474, "timestamp": 1596172888346, "firstDayOfPeriod": "2020-07-01"}, {"code": "CRIX.UPBIT.KRW-BTC", "candleDateTime": "2020-06-01T00:00:00+00:00", "candleDateTimeKst": "2020-06-01T09:00:00+09:00", "openingPrice": 11432000.0, "highPrice": 12230000.0, "lowPrice": 10756000.0, "tradePrice": 10903000.0, "candleAccTradeVolume": 82842.86826319, "candleAccTradePrice": 947354527390.6284, "timestamp": 1593561601838, "firstDayOfPeriod": "2020-06-01"}, {"code": "CRIX.UPBIT.KRW-BTC", "candleDateTime": "2020-05-01T00:00:00+00:00", "candleDateTimeKst": "2020-05-01T09:00:00+09:00", "openingPrice": 10477000.0, "highPrice": 12163000.0, "lowPrice": 10121000.0, "tradePrice": 11432000.0, "candleAccTradeVolume": 188722.04592686, "candleAccTradePrice": 2109939228782.646, "timestamp": 1590969594783, "firstDayOfPeriod": "2020-05-01"}, {"code": "CRIX.UP
code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-07-01T09:00:00+09:00',
#   'openingPrice': 10903000.0,
#   'highPrice': 13368000.0,
#   'lowPrice': 10700000.0,
#   'tradePrice': 13038000.0,
#   'candleAccTradeVolume': 82973.98783208,
#   'candleAccTradePrice': 969841584833.2474,
#   'timestamp': 1596172888346,
#   'firstDayOfPeriod': '2020-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-06-01T09:00:00+09:00',
#   'openingPrice': 11432000.0,
#   'highPrice': 12230000.0,
#   'lowPrice': 10756000.0,
#   'tradePrice': 10903000.0,
#   'candleAccTradeVolume': 82842.86826319,
#   'candleAccTradePrice': 947354527390.6284,
#   'timestamp': 1593561601838,
#   'firstDayOfPeriod': '2020-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-05-01T09:00:00+09:00',
#   'openingPrice': 10477000.0,
#   'highPrice': 12163000.0,
#   'lowPrice': 10121000.0,
#   'tradePrice': 11432000.0,
#   'candleAccTradeVolume': 188722.04592686,
#   'candleAccTradePrice': 2109939228782.646,
#   'timestamp': 1590969594783,
#   'firstDayOfPeriod': '2020-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-04-01T09:00:00+09:00',
#   'openingPrice': 7799000.0,
#   'highPrice': 11435000.0,
#   'lowPrice': 7529000.0,
#   'tradePrice': 10477000.0,
#   'candleAccTradeVolume': 171519.60064021,
#   'candleAccTradePrice': 1524309595907.389,
#   'timestamp': 1588291200393,
#   'firstDayOfPeriod': '2020-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-03-01T09:00:00+09:00',
#   'openingPrice': 10380000.0,
#   'highPrice': 10980000.0,
#   'lowPrice': 5489000.0,
#   'tradePrice': 7799000.0,
#   'candleAccTradeVolume': 345309.78188922,
#   'candleAccTradePrice': 2661304476282.0654,
#   'timestamp': 1585699199936,
#   'firstDayOfPeriod': '2020-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-02-01T09:00:00+09:00',
#   'openingPrice': 10781000.0,
#   'highPrice': 12044000.0,
#   'lowPrice': 10306000.0,
#   'tradePrice': 10374000.0,
#   'candleAccTradeVolume': 141681.39512565,
#   'candleAccTradePrice': 1608632370095.7415,
#   'timestamp': 1583020800101,
#   'firstDayOfPeriod': '2020-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2020-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2020-01-01T09:00:00+09:00',
#   'openingPrice': 8308000.0,
#   'highPrice': 10882000.0,
#   'lowPrice': 7910000.0,
#   'tradePrice': 10781000.0,
#   'candleAccTradeVolume': 151081.46125133,
#   'candleAccTradePrice': 1448009639610.1118,
#   'timestamp': 1580515200123,
#   'firstDayOfPeriod': '2020-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-12-01T09:00:00+09:00',
#   'openingPrice': 8838000.0,
#   'highPrice': 8996000.0,
#   'lowPrice': 7546000.0,
#   'tradePrice': 8312000.0,
#   'candleAccTradeVolume': 88753.43949787,
#   'candleAccTradePrice': 749631042779.4087,
#   'timestamp': 1577836799562,
#   'firstDayOfPeriod': '2019-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-11-01T09:00:00+09:00',
#   'openingPrice': 10698000.0,
#   'highPrice': 10996000.0,
#   'lowPrice': 7683000.0,
#   'tradePrice': 8838000.0,
#   'candleAccTradeVolume': 121988.83863801,
#   'candleAccTradePrice': 1142572317699.0076,
#   'timestamp': 1575158386426,
#   'firstDayOfPeriod': '2019-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-10-01T09:00:00+09:00',
#   'openingPrice': 9945000.0,
#   'highPrice': 11899000.0,
#   'lowPrice': 8630000.0,
#   'tradePrice': 10692000.0,
#   'candleAccTradeVolume': 158003.54559607,
#   'candleAccTradePrice': 1604730480108.4348,
#   'timestamp': 1572566396750,
#   'firstDayOfPeriod': '2019-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-09-01T09:00:00+09:00',
#   'openingPrice': 11612000.0,
#   'highPrice': 13014000.0,
#   'lowPrice': 9268000.0,
#   'tradePrice': 9945000.0,
#   'candleAccTradeVolume': 152291.29161581,
#   'candleAccTradePrice': 1748379097342.2788,
#   'timestamp': 1569887998676,
#   'firstDayOfPeriod': '2019-09-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-08-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-08-01T09:00:00+09:00',
#   'openingPrice': 11956000.0,
#   'highPrice': 14570000.0,
#   'lowPrice': 11380000.0,
#   'tradePrice': 11612000.0,
#   'candleAccTradeVolume': 283765.53137123,
#   'candleAccTradePrice': 3661279344006.8315,
#   'timestamp': 1567295999820,
#   'firstDayOfPeriod': '2019-08-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-07-01T09:00:00+09:00',
#   'openingPrice': 13599000.0,
#   'highPrice': 15537000.0,
#   'lowPrice': 10880000.0,
#   'tradePrice': 11957000.0,
#   'candleAccTradeVolume': 487170.94062848,
#   'candleAccTradePrice': 6321462071944.682,
#   'timestamp': 1564617599890,
#   'firstDayOfPeriod': '2019-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-06-01T09:00:00+09:00',
#   'openingPrice': 10383000.0,
#   'highPrice': 16840000.0,
#   'lowPrice': 9172000.0,
#   'tradePrice': 13598000.0,
#   'candleAccTradeVolume': 395517.38569837,
#   'candleAccTradePrice': 4981181503052.697,
#   'timestamp': 1561939201202,
#   'firstDayOfPeriod': '2019-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-05-01T09:00:00+09:00',
#   'openingPrice': 6117000.0,
#   'highPrice': 10815000.0,
#   'lowPrice': 6107000.0,
#   'tradePrice': 10383000.0,
#   'candleAccTradeVolume': 364387.76327154,
#   'candleAccTradePrice': 3225143397528.754,
#   'timestamp': 1559347198750,
#   'firstDayOfPeriod': '2019-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-04-01T09:00:00+09:00',
#   'openingPrice': 4661000.0,
#   'highPrice': 6566000.0,
#   'lowPrice': 4621000.0,
#   'tradePrice': 6117000.0,
#   'candleAccTradeVolume': 286261.8481024,
#   'candleAccTradePrice': 1666238307040.8777,
#   'timestamp': 1556668799842,
#   'firstDayOfPeriod': '2019-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-03-01T09:00:00+09:00',
#   'openingPrice': 4240000.0,
#   'highPrice': 4680000.0,
#   'lowPrice': 4120000.0,
#   'tradePrice': 4661000.0,
#   'candleAccTradeVolume': 220183.66257353,
#   'candleAccTradePrice': 971178898630.9796,
#   'timestamp': 1554076797634,
#   'firstDayOfPeriod': '2019-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-02-01T09:00:00+09:00',
#   'openingPrice': 3775000.0,
#   'highPrice': 4554000.0,
#   'lowPrice': 3735000.0,
#   'tradePrice': 4240000.0,
#   'candleAccTradeVolume': 149447.01330811,
#   'candleAccTradePrice': 613176329271.873,
#   'timestamp': 1551398399461,
#   'firstDayOfPeriod': '2019-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2019-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2019-01-01T09:00:00+09:00',
#   'openingPrice': 4200000.0,
#   'highPrice': 4577000.0,
#   'lowPrice': 3730000.0,
#   'tradePrice': 3775000.0,
#   'candleAccTradeVolume': 152628.16488031,
#   'candleAccTradePrice': 625565113869.71,
#   'timestamp': 1548979197516,
#   'firstDayOfPeriod': '2019-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-12-01T09:00:00+09:00',
#   'openingPrice': 4565000.0,
#   'highPrice': 4852000.0,
#   'lowPrice': 3562000.0,
#   'tradePrice': 4200000.0,
#   'candleAccTradeVolume': 256196.68711434,
#   'candleAccTradePrice': 1077286128289.1417,
#   'timestamp': 1546300799298,
#   'firstDayOfPeriod': '2018-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-11-01T09:00:00+09:00',
#   'openingPrice': 7162000.0,
#   'highPrice': 7348000.0,
#   'lowPrice': 4126000.0,
#   'tradePrice': 4565000.0,
#   'candleAccTradeVolume': 202770.0644728,
#   'candleAccTradePrice': 1119919084873.1338,
#   'timestamp': 1543622399999,
#   'firstDayOfPeriod': '2018-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-10-01T09:00:00+09:00',
#   'openingPrice': 7394000.0,
#   'highPrice': 7905000.0,
#   'lowPrice': 7057000.0,
#   'tradePrice': 7162000.0,
#   'candleAccTradeVolume': 101664.52766478,
#   'candleAccTradePrice': 746729084717.5271,
#   'timestamp': 1541030395761,
#   'firstDayOfPeriod': '2018-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-09-01T09:00:00+09:00',
#   'openingPrice': 7865000.0,
#   'highPrice': 8333000.0,
#   'lowPrice': 7010000.0,
#   'tradePrice': 7393000.0,
#   'candleAccTradeVolume': 100674.26100622,
#   'candleAccTradePrice': 751712331036.9186,
#   'timestamp': 1538351998003,
#   'firstDayOfPeriod': '2018-09-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-08-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-08-01T09:00:00+09:00',
#   'openingPrice': 8807000.0,
#   'highPrice': 8940000.0,
#   'lowPrice': 6960000.0,
#   'tradePrice': 7865000.0,
#   'candleAccTradeVolume': 150764.1511383,
#   'candleAccTradePrice': 1160146596428.6897,
#   'timestamp': 1535759997980,
#   'firstDayOfPeriod': '2018-08-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-07-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-07-01T09:00:00+09:00',
#   'openingPrice': 7164000.0,
#   'highPrice': 9578000.0,
#   'lowPrice': 6941000.0,
#   'tradePrice': 8800000.0,
#   'candleAccTradeVolume': 181398.01589799,
#   'candleAccTradePrice': 1496143560056.306,
#   'timestamp': 1533081602111,
#   'firstDayOfPeriod': '2018-07-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-06-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-06-01T09:00:00+09:00',
#   'openingPrice': 8278000.0,
#   'highPrice': 8490000.0,
#   'lowPrice': 6590000.0,
#   'tradePrice': 7164000.0,
#   'candleAccTradeVolume': 117782.95477841,
#   'candleAccTradePrice': 884389892618.8875,
#   'timestamp': 1530403203921,
#   'firstDayOfPeriod': '2018-06-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-05-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-05-01T09:00:00+09:00',
#   'openingPrice': 10135000.0,
#   'highPrice': 10963000.0,
#   'lowPrice': 7813000.0,
#   'tradePrice': 8282000.0,
#   'candleAccTradeVolume': 272267.48145009,
#   'candleAccTradePrice': 2607958006238.1025,
#   'timestamp': 1527811206423,
#   'firstDayOfPeriod': '2018-05-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-04-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-04-01T09:00:00+09:00',
#   'openingPrice': 7688000.0,
#   'highPrice': 10755000.0,
#   'lowPrice': 7087000.0,
#   'tradePrice': 10138000.0,
#   'candleAccTradeVolume': 573633.81153136,
#   'candleAccTradePrice': 4959892531222.687,
#   'timestamp': 1525132804146,
#   'firstDayOfPeriod': '2018-04-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-03-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-03-01T09:00:00+09:00',
#   'openingPrice': 11865000.0,
#   'highPrice': 12899000.0,
#   'lowPrice': 7431000.0,
#   'tradePrice': 7697000.0,
#   'candleAccTradeVolume': 575945.75756607,
#   'candleAccTradePrice': 5805373843215.382,
#   'timestamp': 1522540804153,
#   'firstDayOfPeriod': '2018-03-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-02-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-02-01T09:00:00+09:00',
#   'openingPrice': 11439000.0,
#   'highPrice': 14149000.0,
#   'lowPrice': 6620000.0,
#   'tradePrice': 11860000.0,
#   'candleAccTradeVolume': 780683.9588336,
#   'candleAccTradePrice': 8338553933032.581,
#   'timestamp': 1519862403088,
#   'firstDayOfPeriod': '2018-02-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2018-01-01T00:00:00+00:00',
#   'candleDateTimeKst': '2018-01-01T09:00:00+09:00',
#   'openingPrice': 19278000.0,
#   'highPrice': 28885000.0,
#   'lowPrice': 10400000.0,
#   'tradePrice': 11429000.0,
#   'candleAccTradeVolume': 1138495.89407868,
#   'candleAccTradePrice': 20968342926307.7,
#   'timestamp': 1517443201774,
#   'firstDayOfPeriod': '2018-01-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-12-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-12-01T09:00:00+09:00',
#   'openingPrice': 11935000.0,
#   'highPrice': 24967000.0,
#   'lowPrice': 11201000.0,
#   'tradePrice': 19280000.0,
#   'candleAccTradeVolume': 1423404.06885122,
#   'candleAccTradePrice': 27132793421335.008,
#   'timestamp': 1514764800514,
#   'firstDayOfPeriod': '2017-12-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-11-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-11-01T09:00:00+09:00',
#   'openingPrice': 7422000.0,
#   'highPrice': 13750000.0,
#   'lowPrice': 6476000.0,
#   'tradePrice': 11935000.0,
#   'candleAccTradeVolume': 332870.40658095,
#   'candleAccTradePrice': 3333919267614.687,
#   'timestamp': 1512086401121,
#   'firstDayOfPeriod': '2017-11-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-10-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-10-01T09:00:00+09:00',
#   'openingPrice': 4889000.0,
#   'highPrice': 7479000.0,
#   'lowPrice': 4682000.0,
#   'tradePrice': 7422000.0,
#   'candleAccTradeVolume': 4282.09567791,
#   'candleAccTradePrice': 28792318723.58634,
#   'timestamp': 1509494399256,
#   'firstDayOfPeriod': '2017-10-01'},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'candleDateTime': '2017-09-01T00:00:00+00:00',
#   'candleDateTimeKst': '2017-09-01T09:00:00+09:00',
#   'openingPrice': 4201000.0,
#   'highPrice': 4896000.0,
#   'lowPrice': 4175000.0,
#   'tradePrice': 4895000.0,
#   'candleAccTradeVolume': 347.48185656,
#   'candleAccTradePrice': 1544805967.39643,
#   'timestamp': 1506815987704,
#   'firstDayOfPeriod': '2017-09-01'}]

# %% [markdown]
# ## 와디즈

# %%
base_url = 'https://www.wadiz.kr/web/wreward/ajaxGetCardList'
params ={
    'startNum': 0,
    'limit': 100,#갯수 제한
    'order': 'recommend',
    'keyword':'',
    'endYn':'ALL'
}
resp = requests.get(base_url, params= params)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

#_data= data['data']
#len(_data)#dic형태
#_data

# %% [markdown]
# # 데이터
# 정형데이터: 구조화된 데이터
# 비정형데이터 : binary 파일 등 이미지, 음악, 영상-> 틀이 정해져 있지 않음!
#
# <이미지 저장>
# 웹에서 이미지가 보인다는건 리퀘스트를 날린것
#
# 수집하는 방법 ->
# 1)파일에 해당 이미지의 URL을 저장
# 2)실제 이미지를 내 컴퓨터에 저장하고, 저장된 이미지의 경로를 저장
# -> 이미지가 파일이 많아지고 크면, 올리는 메모리의 양이 한정되어 있기 때문에. 비효율적
# 3)실제 이미지 binary를 저장함.

# %% [markdown]
# # 이미지 저장

# %%
url = 'https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F001%2F2020%2F07%2F31%2F11783389.jpg&type=ofullfill80_80_q75_re2'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.content#content는 binary파일, text str
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00P\x00P\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x07\x05\x08\x06\xff\xc4\x002\x10\x00\x01\x02\x04\x03\x07\x04\x01\x03\x05\x01\x00\x00\x00\x00\x00\x01\x02\x03\x00\x04\x05\x11\x06\x12!\x07\x131AQa\xa1\x14"R\x912\x15q\xf0\x16#\x81\xb1\xc1\xf1\xff\xc4\x00\x17\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\xff\xc4\x00\x1d\x11\x01\x01\x01\x01\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x01\x00\x11\x02\x12!1\x03\x13A\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xdf\xe0\x8a\xe2m\xb3\xc9_P\xbe\xa9\x1d\x15\xf5\tO\x04B&\x10y*\x1d\xbeOC\tI\x043z\x9e\x86\x11\x0f\xb6\xe0\xba\x15\x98v\x89\xa7\xc9I\x0470\xef\x0b\x98E\x92\xc1\t\x98AxK\x96!\xe2\x18!\xe2\x12zb\x94\xddz\x91OYD\xe5NN]c\x8a]})>LU\xc4U\xa9J\x05\x1af\xa5>\xb2\x89f\x10T
c6v\x89\x02\xead\x9bx:~\xc4C\xbeT\xf5\x07\x1bYmam\xa5B\xda\x8eF\xe3\xee\x1dxj\x12\x10\x9c\xb9\x89\xeeL:4n{\xa3r\xc2z\xc4SAa\xb4\xa9\x04\x8c\xa6\xe4\xdf\x95\x8f\xfd\xb4X\x88\x9fk|\xda\x924\xb8\xe3\x18\xfdyz\xe1\x0b\\8\xed\xe7:\xb5M\xaa\x0e+\xc5\xd5\xf7\x1b\x0e\xbej\xa2I\x94\x15X\xe4\xf7\x97\x08\xfd\x82\x10\x01\xef\x0f\xc4\x18\xba\x89?\x83TY\x99jbg:7l\xbe\xd8%\x06\xfa\xdd\'\xf2\xd2\xfa\xf0\xf1\x1d\x9ca\xb2:\xcc\xf4\xf3\xf3\xb2s)\x9eq\xf7\x96\xea\x99Z\xf2\xddG\xa5\xc8\x03\xa7\xd4|\xdd/b\xd5\xb9\x85\xcd"\xa4\xdb\xb2)JB\x9aq\x1b\xb7\x92\xe7^\x0b\x07\xf9\xc6/\x9f;\xf6\x98\xd5\x9f\xc4\x94\xf7*\xb4\x8a\xcd\x1d\x96e\xe7P\x84KO0\xdbY[P6\xf7\'M,t\xfa\x8e&(\xaa\xbfU\xaf\xceM\xa9i\xbb\x81(Jt)\xfct\xb5\xff\x00\xdc}\xc2v\x1d[\x13DS\xa7\xe5\xd1&\xe0H[\x8f\xdd.\x01pM\x92\x01\x06\xd6\xd3Q\x16f6\x1f8\x0be\x15$\xb8\xe8\xbe\xf9\xc7\xc9H\x1d\nBA\xefpO(\xbdw\xcf&\xac\x05\xf4Y\xca\xf1\x9c\xe4\xc6\x18f\x8c\xf1\'t\xb0K\x85D\x85\xa0$\x80\x92\x0e\x9au\xed\xd7X\xd0\xf6\x11Q\x96\x18\x82u\x92\x945?3,P\xc3\x81:hB\x94,4\xbd\x807\xed\x17\x86\xc5\x8b43),\xb99\x89\xd7\x1e\xde.a\xf4)>\xc1\x7fjx\xd8p7\xd2\xf7\x8e\xa6\x0e\ ...

# %%
with open('temp.jpg', 'wb') as f:#write binary
    f.write(resp.content)

# %% [markdown]
# # headers

# %%
resp = requests.get("https://www.naver.com")
resp
# Out:
# <Response [200]>

# %%
resp.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
headers = {
    'User_Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
    'referer':'https://naver.com'
}

# %%
resp =  requests.get('https://naver.com', headers= headers)
resp
# Out:
# <Response [200]>

# %%
resp.request.headers#해더 변경하기
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'User_Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36', 'referer': 'https://naver.com'}

# %% [markdown]
# # 실습
# 데이터 3일치

# %% [markdown]
# # IT과학의 기사 리스트
# n일치 3일치
# - 기사 리스트: [{
#     'id': ~~,
#     'title': ~~~~,
#      'img': ~~~,
#     'content': ~~~~,
#     'comments': [
#         {
#             'author': ~~~,
#             'content': ~~~~
#         }
#     ]
#
# }]

# %%
import requests

# %%
base_url = 'https://news.naver.com/main/list.nhn'
params = {
    'mode': 'LS2D',
    'sid2':731,
    'sid1':105,
    'mid':'shm',
    'date':20200730,
    'page':4
}

resp = requests.get(base_url, params= params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text)
ul_tags = soup.find('ul', class_='type06_headline')
news_li = ul_tags.find_all('li', recursive=False)
print(len(news_li))
news_li
# Out:
# 10
# [<li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=138&amp;aid=0002089447">
#  <img alt="[일문일답] LGU+, 비대면 판매채널 공략 “온라인 매출 3배 늘린다”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/138/2020/07/30/2089447.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=138&amp;aid=0002089447">
#  								 [일문일답] LGU+, 비대면 판매채널 공략 “온라인 매출 3배 늘린다”
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">[디지털데일리 최민지기자] 코로나19 이후 온라인 구매 경험이 폭발적으로 늘어난 가운데, MZ세대는 실시간 라이브 쇼핑이라는 새 …</span>
#  <span class="writing">디지털데일리</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=003&amp;aid=0009995759">
#  <img alt='네이버 한성숙의 자신감…"코로나 현 수준이면 연초 목표 달성 가능"' height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/003/2020/07/30/9995759.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=003&amp;aid=0009995759">
#  								 네이버 한성숙의 자신감…"코로나 현 수준이면 연초 목표 달성 가능"
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">[서울=뉴시스] 이진영 기자 = 한성숙 네이버 대표는 30일 "코로나19 영향이 현재 수준으로 이어질 경우 연초에 (내부적으로) …</span>
#  <span class="writing">뉴시스</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=018&amp;aid=0004701901">
#  <img alt="삼성폰, 2분기 ‘슈퍼세이브’…“5G·폴더블로 실적개선 이끌것”(종합)" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/018/2020/07/30/4701901.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=018&amp;aid=0004701901">
#  								 삼성폰, 2분기 ‘슈퍼세이브’…“5G·폴더블로 실적개선 이끌것”(종합)
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">[이데일리 장영은 기자] 삼성전자(005930) 스마트폰 사업이 최악의 ‘보릿고개’로 예상됐던 올해 2분기를 무난히 넘겼다. 코 …</span>
#  <span class="writing">이데일리</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780522">
#  <img alt="2분기 선방한 삼성폰…하반기 갤럭시노트 출시로 '청신호'(종합)" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/001/2020/07/30/11780522.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780522">
#  								 2분기 선방한 삼성폰…하반기 갤럭시노트 출시로 '청신호'(종합)
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">매출 감소에도 수익성 유지…"3분기 플래그십 신모델로 실적 개선" "6월부터 시장 회복세…중저가 모델 안정적 수익성 확보 노력" …</span>
#  <span class="writing">연합뉴스</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=421&amp;aid=0004786062">
#  <img alt="[IR종합] 삼성전자 &quot;5G폰·Z폴드 '新 쌍두마차'로 수요부진 대응&quot;" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/421/2020/07/30/4786062.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=421&amp;aid=0004786062">
#  								 [IR종합] 삼성전자 "5G폰·Z폴드 '新 쌍두마차'로 수요부진 대응"
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">(서울=뉴스1) 강은성 기자,김정현 기자 = 삼성전자가 신종 코로나바이러스 감염증(코로나19) 여파로 2분기 프리미엄폰 판매가  …</span>
#  <span class="writing">뉴스1</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780514">
#  <img alt="미중 갈등 속에서도 애플·테슬라 중국 매출 급증" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/001/2020/07/30/11780514.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780514">
#  								 미중 갈등 속에서도 애플·테슬라 중국 매출 급증
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">2분기 테슬라 매출 2배로 늘어…애플 판매 증가세 중국업체 앞서 (베이징=연합뉴스) 김윤구 특파원 = 미국과 중국 간의 갈등 속 …</span>
#  <span class="writing">연합뉴스</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=092&amp;aid=0002195177">
#  <img alt='삼성전자 "2Q 휴대폰 판매량 5천700만대, 3Q 증가 예상"' height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/092/2020/07/30/2195177.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=092&amp;aid=0002195177">
#  								 삼성전자 "2Q 휴대폰 판매량 5천700만대, 3Q 증가 예상"
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">(지디넷코리아=황정빈 기자)삼성전자의 지난 2분기 휴대폰 판매량이 5천700만대인 것으로 집계됐다. 3분기에는 판매량이 증가할  …</span>
#  <span class="writing">ZDNet Korea</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=421&amp;aid=0004786011">
#  								 [IR] 삼성 "해외 5G 투자 불확실성 有…긴밀한 협의로 영향 최소화"
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">(서울=뉴스1) 김정현 기자 = 삼성전자는 30일 열린 2020년 2분기 실적발표 콘퍼런스콜에서 "국내의 경우 지난해 5세대(5 …</span>
#  <span class="writing">뉴스1</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780415">
#  <img alt="샤오미 미10라이트 5G, KT 직영매장서 AS 받는다" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/001/2020/07/30/11780415.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780415">
#  								 샤오미 미10라이트 5G, KT 직영매장서 AS 받는다
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">(서울=연합뉴스) 채새롬 기자 = 샤오미는 8월 중 전국 KT 직영매장에서 자사 스마트폰 '미10라이트 5G'의 불량진단, 불량 …</span>
#  <span class="writing">연합뉴스</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>,
#  <li>
#  <dl>
#  <dt class="photo">
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780387">
#  <img alt="[게시판] 성신여대-SK텔레콤, AI 교육협력 MOU 체결" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/001/2020/07/30/11780387.jpg?type=nf106_72" width="106"/>
#  </a>
#  </dt>
#  <dt>
#  <a href="https://news.naver.com/main/read.nhn?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731&amp;oid=001&amp;aid=0011780387">
#  								 [게시판] 성신여대-SK텔레콤, AI 교육협력 MOU 체결
#  								</a>
#  </dt>
#  <dd>
#  <span class="lede">▲ 성신여대와 SK텔레콤이 인공지능(AI) 기술 분야 협력과 커리큘럼 운영을 위한 양해각서(MOU)를 체결했다. 양측은 앞으로  …</span>
#  <span class="writing">연합뉴스</span>
#  <span class="date is_outdated">1일전</span>
#  </dd>
#  </dl>
#  </li>]

# %%
result_list = []

for news in news_li:
    title_tag = news.find('a', class_= "")
    title = title_tag.text
    url = title_tag.get('href')
    
    desc = news.find_all('dd')
    desc = desc[1].text
    result_list.append({
        'title': title,
        'url': url,
        'desc': desc
    })
print(len(result_list))
result_list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-221-683ef4c19b58> in <module>
#       7
#       8     desc = news.find_all('dd')
# ----> 9     desc = desc[1].text
#      10     result_list.append({
#      11         'title': title,
#
# IndexError: list index out of range

# %%
result_list=[]

titles = soup.select('ul.type06_headline>li>dl>dt>a')
title_tag = news.find('a', class_ = "")
url = title_tag.get('href')
    
    #desc = news.find_all('dd')
    #  desc = desc[1].text
    result_list.append({
        'title': titles,
        'url': url
    })
print(len(result_list))
result_list
# Out:
#   File "<ipython-input-211-26d7bd6fa721>", line 9
#     result_list.append({
#     ^
# IndentationError: unexpected indent
